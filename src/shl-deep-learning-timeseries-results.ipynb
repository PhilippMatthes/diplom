# %% [markdown]
# <a href="https://colab.research.google.com/github/PhilippMatthes/diplom/blob/master/src/shl-deep-learning-timeseries-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/philippmatthes/diplom
# Out:
# Cloning into 'diplom'...
# remote: Enumerating objects: 2183, done.
# remote: Counting objects: 100% (1520/1520), done.
# remote: Compressing objects: 100% (1061/1061), done.
# remote: Total 2183 (delta 769), reused 1054 (delta 383), pack-reused 663
# Receiving objects: 100% (2183/2183), 55.57 MiB | 21.38 MiB/s, done.
# Resolving deltas: 100% (1145/1145), done.

# %%
# Switch to our src dir for further processing. This command is specific to 
# Google Colab, so it might not work on your local Jupyter Notebook instance

# %cd /content/diplom/src
# Out:
# /content/diplom/src

# %%
# Mount Google Drive for data analysis

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy current savestate from gridsearch

datestr = '2021-08-29'

# !mkdir /content/diplom/src/logs/
# !unzip -n -d /content/diplom/src/logs/shl-gridsearch/ /content/drive/MyDrive/logs-{datestr}.zip
# !unzip -n -d /content/diplom/src/models/shl-gridsearch/ /content/drive/MyDrive/gridsearch-{datestr}.zip
# Out:
# Archive:  /content/drive/MyDrive/logs-2021-08-29.zip
#    creating: /content/diplom/src/logs/shl-gridsearch/0e010614e8698e02de6ea84ac08ea92a/
#    creating: /content/diplom/src/logs/shl-gridsearch/17153f2a4bded620e375defd834ae96b/
#    creating: /content/diplom/src/logs/shl-gridsearch/19b9fc45f42649dd56aa7eb9df5d6b2f/
#    creating: /content/diplom/src/logs/shl-gridsearch/19d78461c5cb3c172b13f099311ea77b/
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/
#    creating: /content/diplom/src/logs/shl-gridsearch/35d1710beb7573fa3d55a684e5e5d9a5/
#    creating: /content/diplom/src/logs/shl-gridsearch/4ad2e771492aac5b42c89d9b5a835857/
#    creating: /content/diplom/src/logs/shl-gridsearch/4fafcd413fb89ba4ec2a052fdcc89ccb/
#    creating: /content/diplom/src/logs/shl-gridsearch/54579b011617e730136c7dc8c4f019b3/
#    creating: /content/diplom/src/logs/shl-gridsearch/60f59273ac339360b2b838511a3affd1/
#    creating: /content/diplom/src/logs/shl-gridsearch/6af8a156f95b675b9ae9689d66c25b64/
#    creating: /content/diplom/src/logs/shl-gridsearch/6f7747c36067eecf4a1938dd5c1ee3c7/
#    creating: /content/diplom/src/logs/shl-gridsearch/74f905b3244c57578f3e079db7d6910b/
#    creating: /content/diplom/src/logs/shl-gridsearch/7523152748da6ca5d4d59234b3732c89/
#    creating: /content/diplom/src/logs/shl-gridsearch/7a39bbea52d7a11d80c7cf395e409540/
#    creating: /content/diplom/src/logs/shl-gridsearch/7cfd6602ff1ee897fd95deebf54ec24a/
#    creating: /content/diplom/src/logs/shl-gridsearch/8aaa2b0d4bc28323ec5e5dda2b99b600/
#    creating: /content/diplom/src/logs/shl-gridsearch/92cf7c46d280478beb399b503d6773fd/
#    creating: /content/diplom/src/logs/shl-gridsearch/968ca3e771b5efa5855ba841f69c463a/
#    creating: /content/diplom/src/logs/shl-gridsearch/9988226d7297eb039365ad50f7c5ea0b/
#    creating: /content/diplom/src/logs/shl-gridsearch/acc67cefc8f3e1f363b7be2278c5d6f8/
#    creating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/
#    creating: /content/diplom/src/logs/shl-gridsearch/cb5048dd197b94c8b420dbcdb49f378f/
#    creating: /content/diplom/src/logs/shl-gridsearch/d120ad51d82d8966654d38c0bed18f6f/
#    creating: /content/diplom/src/logs/shl-gridsearch/d5912676257ab43a4b8b0c94a0771fc2/
#    creating: /content/diplom/src/logs/shl-gridsearch/e6c36740f115fc7510ff472225bedeac/
#    creating: /content/diplom/src/logs/shl-gridsearch/ea70373fe386b068ffab6704b4ac25fc/
#    creating: /content/diplom/src/logs/shl-gridsearch/ed78d79eceb0d22006ed16af20d1cc5a/
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/validation/
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/events.out.tfevents.1629982109.8e926b251158.6934.15.v2
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/validation/events.out.tfevents.1629985580.8e926b251158.6934.17.v2
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/events.out.tfevents.1629982157.8e926b251158.profile-empty
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/events.out.tfevents.1629982115.8e926b251158.6934.16.v2
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/
#    creating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.trace.json.gz
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.input_pipeline.pb
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.memory_profile.json.gz
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.overview_page.pb
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.kernel_stats.pb
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.tensorflow_stats.pb
#   inflating: /content/diplom/src/logs/shl-gridsearch/2e36450ad2968ef7e675fa3e350736e1/execution0/train/plugins/profile/2021_08_26_12_49_17/8e926b251158.xplane.pb
#    creating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/
#    creating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/train/
#    creating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/validation/
#   inflating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/events.out.tfevents.1629995913.8e926b251158.6934.39.v2
#   inflating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/validation/events.out.tfevents.1629996100.8e926b251158.6934.41.v2
#    creating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/train/plugins/
#   inflating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0/train/events.out.tfevents.1629995918.8e926b251158.profile-empty
#   inflating: /content/diplom/src/logs/shl-gridsearch/bf1ba8ba4a66f98b650f95f4ff56665e/execution0
(1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.15.0)

# %%
import os
import json
import tempfile
import shutil
import zipfile

from packaging import version
from pathlib import Path
from collections import defaultdict

import tensorflow as tf
import pandas as pd
import tensorboard as tb
import numpy as np

from google.colab.files import download
from matplotlib import pyplot as plt
from tensorboard.backend.event_processing import event_accumulator

major_ver, minor_ver, _ = version.parse(tb.__version__).release
assert major_ver >= 2 and minor_ver >= 3, \
    "This notebook requires TensorBoard 2.3 or later."
print("TensorBoard version: ", tb.__version__)
# Out:
# TensorBoard version:  2.6.0

# %%
def parse_gridsearch_tf_logs(
    log_dir: Path, 
    metric_sources=['train', 'validation'],
    metrics=['epoch_loss', 'epoch_acc'],
) -> dict:
    data = defaultdict(dict)

    for trial_dir in [d for d in log_dir.iterdir() if d.is_dir()]:
        trial_id = trial_dir.parts[-1]
        
        for metric in metrics:
            for metric_source in metric_sources:
                ea = event_accumulator.EventAccumulator(
                    str(trial_dir / 'execution0' / metric_source),
                    size_guidance={event_accumulator.TENSORS: 0}
                )
                ea.Reload()

                if metric not in ea.Tags()['tensors']:
                    continue

                metric_tensors = ea.Tensors(metric)

                data[f'{metric_source}_{metric}'][trial_id] = {
                    'epochs': [t.step for t in metric_tensors],
                    'values': [tf.make_ndarray(t.tensor_proto) for t in metric_tensors],
                    'dates': [t.wall_time for t in metric_tensors],
                }
    
    return data

parsed_data = parse_gridsearch_tf_logs(Path('logs/shl-gridsearch'))

# %%
plt.clf()

fig, axs = plt.subplots(1, len(parsed_data))
fig.set_size_inches(3 * len(parsed_data), 4)

metric_labels = {
    'train_epoch_loss': 'Train Loss (Log-Skala)',
    'validation_epoch_loss': 'Validation Loss (Log-Skala)',
    'train_epoch_acc': 'Train Accuracy (in %)',
    'validation_epoch_acc': 'Validation Accuracy (in %)',
}

metric_scales = {
    'train_epoch_loss': 'log',
    'validation_epoch_loss': 'log',
    'train_epoch_acc': 'linear',
    'validation_epoch_acc': 'linear',
}

for ax, (metric, trials_data) in zip(axs, parsed_data.items()):
    for trial_id, data in trials_data.items():
        y = data['values']
        ax.plot(y, color=(0, 0, 0, 0.5))
        ax.set_yscale(metric_scales[metric])
        ax.grid(
            b = True, 
            color ='grey',
            linestyle ='-.', 
            linewidth = 0.5,
            alpha = 0.2
        )
    ax.set_ylabel(metric_labels[metric])
    ax.set_xlabel('Epochen')

axs[0].set_ylim(0, 100)
axs[1].set_ylim(0, 100)
axs[2].set_ylim(0.5, 0.95)
axs[2].set_yticklabels([int(t * 100) for t in axs[2].get_yticks()])
axs[3].set_ylim(0.5, 0.95)
axs[3].set_yticklabels([int(t * 100) for t in axs[3].get_yticks()])

plt.tight_layout()
plt.savefig(
    f'../images/shl/gridsearch-results.pdf',
    dpi=1200,
    bbox_inches='tight'
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
download('../images/shl/gridsearch-results.pdf')

# %%
plt.clf()

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()

diffs = []

for metric, trials_data in parsed_data.items():
    for trial_id, data in trials_data.items():
        dates = data['dates']
        diffs.append((dates[-1] - dates[0]) / len(dates) / 60)

ax1.set_yticks([])

ax1.hist(diffs, 20, color='grey')

ax1.set_xlabel('Durchschnittliche Trainingszeit pro Epoche in Minuten')
ax1.set_ylabel('Relative Anzahl Modelle')

ax2.set_xlim(ax1.get_xlim())
ax2.set_xticklabels([(t * 15) / 60 for t in ax1.get_xticks()])
ax2.set_xlabel('Geschätzte Finalisierungszeit für 15 Epochen in Stunden')

plt.savefig(
    f'../images/shl/gridsearch-finalization-prediction.pdf',
    dpi=1200,
    bbox_inches='tight'
)

# %%
download('../images/shl/gridsearch-finalization-prediction.pdf')

# %%
oracle_dir = Path('models/shl-gridsearch')

def load_trial_data():
    trial_data = defaultdict(dict)

    for trial_dir in [d for d in oracle_dir.iterdir() if d.is_dir()]:
        trial_json_dir = trial_dir / 'trial.json'
        with open(trial_json_dir) as f:
            trial_json = json.loads(f.read())
        trial_id = trial_json['trial_id']
        trial_hps = trial_json['hyperparameters']['values']
        for hp, hp_value in trial_hps.items():
            trial_data[hp][trial_id] = hp_value
        for metric, trials_data in parsed_data.items():
            if trial_id not in trials_data:
                continue
            trial_data[metric][trial_id] = trials_data[trial_id]['values']
    
    return trial_data

# %%
df = pd.DataFrame(load_trial_data())

del df['tuner/initial_epoch']
del df['tuner/bracket']
del df['tuner/round']
del df['tuner/trial_id']
del df['train_epoch_loss']
del df['validation_epoch_loss']

df.dropna(inplace=True)

df['n_epochs'] = df['validation_epoch_acc'].apply(lambda x: len(x))
df['best_epoch'] = df['validation_epoch_acc'].apply(lambda x: np.where(x == np.amax(x))[0][0] + 1)
df['max_train_acc_pct'] = df['train_epoch_acc'].apply(lambda x: np.amax(x) * 100)
df['max_validation_acc_pct'] = df['validation_epoch_acc'].apply(lambda x: np.amax(x) * 100)

del df['tuner/epochs']
del df['validation_epoch_acc']
del df['train_epoch_acc']

df.sort_values(by=['max_validation_acc_pct', 'max_train_acc_pct'], inplace=True, ascending=False)

df = df[[
    'model_type',
    'version',
    'pooling',
    'optimizer',
    'conv3_depth',
    'conv4_depth',
    'n_stacks',
    'learning_rate',
    'n_epochs',
    'best_epoch',
    'max_train_acc_pct',
    'max_validation_acc_pct',
]]

df.rename(columns={
    'model_type': 'Typ',
    'version': 'Version',
    'conv3_depth': 'Tiefe Conv-3',
    'conv4_depth': 'Tiefe Conv-4',
    'n_stacks': 'Stacks',
    'pooling': 'Pooling',
    'optimizer': 'Optimizer',
    'learning_rate': 'Learning Rate',
    'n_epochs': 'Epochen',
    'best_epoch': 'Beste Epoche',
    'max_train_acc_pct': 'Train Acc. (in \%)',
    'max_validation_acc_pct': 'Val. Acc. (in \%)',
}, inplace=True)
df.reset_index(inplace=True)

del df['index']

styled_df = df.style.background_gradient(cmap='binary')
styled_df
# Out:
# <style type="text/css">
# #T_7dffa_row0_col4, #T_7dffa_row0_col7, #T_7dffa_row0_col11, #T_7dffa_row1_col4, #T_7dffa_row1_col5, #T_7dffa_row1_col6, #T_7dffa_row2_col5, #T_7dffa_row2_col7, #T_7dffa_row2_col8, #T_7dffa_row2_col9, #T_7dffa_row2_col10, #T_7dffa_row4_col5, #T_7dffa_row5_col4, #T_7dffa_row6_col4, #T_7dffa_row6_col7, #T_7dffa_row7_col5, #T_7dffa_row8_col4, #T_7dffa_row9_col5, #T_7dffa_row10_col4, #T_7dffa_row10_col5, #T_7dffa_row10_col6, #T_7dffa_row11_col4, #T_7dffa_row12_col4, #T_7dffa_row14_col4, #T_7dffa_row15_col4, #T_7dffa_row15_col5, #T_7dffa_row15_col7, #T_7dffa_row16_col4, #T_7dffa_row16_col5, #T_7dffa_row16_col6, #T_7dffa_row17_col4, #T_7dffa_row17_col5, #T_7dffa_row18_col4, #T_7dffa_row20_col4, #T_7dffa_row20_col6, #T_7dffa_row21_col4, #T_7dffa_row21_col5, #T_7dffa_row22_col5, #T_7dffa_row22_col7, #T_7dffa_row23_col6, #T_7dffa_row23_col7, #T_7dffa_row24_col5, #T_7dffa_row25_col5, #T_7dffa_row26_col7, #T_7dffa_row27_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7dffa_row0_col5, #T_7dffa_row6_col5, #T_7dffa_row8_col5, #T_7dffa_row13_col5, #T_7dffa_row14_col5, #T_7dffa_row18_col5, #T_7dffa_row19_col5, #T_7dffa_row26_col5 {
#   background-color: #6e6e6e;
#   color: #f1f1f1;
# }
# #T_7dffa_row0_col6, #T_7dffa_row3_col6, #T_7dffa_row5_col6, #T_7dffa_row6_col6, #T_7dffa_row8_col6, #T_7dffa_row9_col6, #T_7dffa_row11_col6, #T_7dffa_row12_col6, #T_7dffa_row13_col6, #T_7dffa_row19_col6, #T_7dffa_row26_col6 {
#   background-color: #aaaaaa;
#   color: #f1f1f1;
# }
# #T_7dffa_row0_col8, #T_7dffa_row1_col8, #T_7dffa_row4_col8, #T_7dffa_row5_col8 {
#   background-color: #626262;
#   color: #f1f1f1;
# }
# #T_7dffa_row0_col9, #T_7dffa_row4_col9 {
#   background-color: #5b5b5b;
#   color: #f1f1f1;
# }
# #T_7dffa_row0_col10 {
#   background-color: #656565;
#   color: #f1f1f1;
# }
# #T_7dffa_row1_col7, #T_7dffa_row3_col7, #T_7dffa_row5_col7, #T_7dffa_row8_col7, #T_7dffa_row9_col7, #T_7dffa_row10_col7, #T_7dffa_row11_col7, #T_7dffa_row12_col7, #T_7dffa_row13_col7, #T_7dffa_row14_col7, #T_7dffa_row16_col7, #T_7dffa_row17_col7, #T_7dffa_row18_col7, #T_7dffa_row19_col7, #T_7dffa_row21_col7, #T_7dffa_row24_col7, #T_7dffa_row25_col7 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_7dffa_row1_col9 {
#   background-color: #6d6d6d;
#   color: #f1f1f1;
# }
# #T_7dffa_row1_col10 {
#   background-color: #5e5e5e;
#   color: #f1f1f1;
# }
# #T_7dffa_row1_col11 {
#   background-color: #0d0d0d;
#   color: #f1f1f1;
# }
# #T_7dffa_row2_col4, #T_7dffa_row3_col4, #T_7dffa_row3_col5, #T_7dffa_row4_col4, #T_7dffa_row4_col7, #T_7dffa_row5_col5, #T_7dffa_row7_col4, #T_7dffa_row7_col7, #T_7dffa_row9_col4, #T_7dffa_row11_col5, #T_7dffa_row12_col5, #T_7dffa_row12_col8, #T_7dffa_row13_col4, #T_7dffa_row14_col6, #T_7dffa_row14_col8, #T_7dffa_row15_col6, #T_7dffa_row16_col8, #T_7dffa_row16_col10, #T_7dffa_row17_col6, #T_7dffa_row18_col6, #T_7dffa_row19_col4, #T_7dffa_row19_col8, #T_7dffa_row20_col5, #T_7dffa_row20_col7, #T_7dffa_row20_col8, #T_7dffa_row21_col6, #T_7dffa_row21_col8, #T_7dffa_row22_col4, #T_7dffa_row22_col6, #T_7dffa_row22_col8, #T_7dffa_row23_col4, #T_7dffa_row23_col5, #T_7dffa_row23_col8, #T_7dffa_row24_col4, #T_7dffa_row24_col6, #T_7dffa_row24_col8, #T_7dffa_row25_col4, #T_7dffa_row25_col6, #T_7dffa_row25_col8, #T_7dffa_row25_col9, #T_7dffa_row26_col4, #T_7dffa_row26_col8, #T_7dffa_row26_col11, #T_7dffa_row27_col4, #T_7dffa_row27_col5, #T_7dffa_row27_col6, #T_7dffa_row27_col8, #T_7dffa_row27_col11 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_7dffa_row2_col6, #T_7dffa_row4_col6, #T_7dffa_row7_col6 {
#   background-color: #555555;
#   color: #f1f1f1;
# }
# #T_7dffa_row2_col11 {
#   background-color: #0e0e0e;
#   color: #f1f1f1;
# }
# #T_7dffa_row3_col8 {
#   background-color: #b1b1b1;
#   color: #000000;
# }
# #T_7dffa_row3_col9, #T_7dffa_row7_col9, #T_7dffa_row10_col9, #T_7dffa_row11_col9, #T_7dffa_row13_col9 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_7dffa_row3_col10 {
#   background-color: #7b7b7b;
#   color: #f1f1f1;
# }
# #T_7dffa_row3_col11 {
#   background-color: #2b2b2b;
#   color: #f1f1f1;
# }
# #T_7dffa_row4_col10 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_7dffa_row4_col11, #T_7dffa_row5_col10 {
#   background-color: #313131;
#   color: #f1f1f1;
# }
# #T_7dffa_row5_col9 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
# }
# #T_7dffa_row5_col11 {
#   background-color: #3d3d3d;
#   color: #f1f1f1;
# }
# #T_7dffa_row6_col8, #T_7dffa_row7_col8, #T_7dffa_row8_col8, #T_7dffa_row9_col8, #T_7dffa_row15_col8, #T_7dffa_row17_col8 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_7dffa_row6_col9, #T_7dffa_row9_col9, #T_7dffa_row12_col10, #T_7dffa_row15_col9, #T_7dffa_row17_col9 {
#   background-color: #b6b6b6;
#   color: #000000;
# }
# #T_7dffa_row6_col10 {
#   background-color: #969696;
#   color: #f1f1f1;
# }
# #T_7dffa_row6_col11 {
#   background-color: #3e3e3e;
#   color: #f1f1f1;
# }
# #T_7dffa_row7_col10 {
#   background-color: #8e8e8e;
#   color: #f1f1f1;
# }
# #T_7dffa_row7_col11 {
#   background-color: #616161;
#   color: #f1f1f1;
# }
# #T_7dffa_row8_col9 {
#   background-color: #c9c9c9;
#   color: #000000;
# }
# #T_7dffa_row8_col10, #T_7dffa_row9_col10 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_7dffa_row8_col11 {
#   background-color: #636363;
#   color: #f1f1f1;
# }
# #T_7dffa_row9_col11 {
#   background-color: #686868;
#   color: #f1f1f1;
# }
# #T_7dffa_row10_col8, #T_7dffa_row11_col8, #T_7dffa_row13_col8, #T_7dffa_row18_col8, #T_7dffa_row24_col10 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_7dffa_row10_col10, #T_7dffa_row17_col10, #T_7dffa_row20_col11 {
#   background-color: #bcbcbc;
#   color: #000000;
# }
# #T_7dffa_row10_col11 {
#   background-color: #6a6a6a;
#   color: #f1f1f1;
# }
# #T_7dffa_row11_col10 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_7dffa_row11_col11 {
#   background-color: #737373;
#   color: #f1f1f1;
# }
# #T_7dffa_row12_col9, #T_7dffa_row14_col9, #T_7dffa_row16_col9, #T_7dffa_row18_col9, #T_7dffa_row19_col9, #T_7dffa_row20_col9, #T_7dffa_row21_col9, #T_7dffa_row22_col9, #T_7dffa_row23_col9, #T_7dffa_row24_col9, #T_7dffa_row26_col9, #T_7dffa_row27_col9 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_7dffa_row12_col11 {
#   background-color: #838383;
#   color: #f1f1f1;
# }
# #T_7dffa_row13_col10, #T_7dffa_row19_col11 {
#   background-color: #a6a6a6;
#   color: #f1f1f1;
# }
# #T_7dffa_row13_col11 {
#   background-color: #878787;
#   color: #f1f1f1;
# }
# #T_7dffa_row14_col10, #T_7dffa_row21_col10 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_7dffa_row14_col11 {
#   background-color: #8d8d8d;
#   color: #f1f1f1;
# }
# #T_7dffa_row15_col10 {
#   background-color: #b0b0b0;
#   color: #000000;
# }
# #T_7dffa_row15_col11 {
#   background-color: #909090;
#   color: #f1f1f1;
# }
# #T_7dffa_row16_col11 {
#   background-color: #9d9d9d;
#   color: #f1f1f1;
# }
# #T_7dffa_row17_col11 {
#   background-color: #a3a3a3;
#   color: #f1f1f1;
# }
# #T_7dffa_row18_col10, #T_7dffa_row25_col10 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_7dffa_row18_col11 {
#   background-color: #a5a5a5;
#   color: #f1f1f1;
# }
# #T_7dffa_row19_col10 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_7dffa_row20_col10 {
#   background-color: #cbcbcb;
#   color: #000000;
# }
# #T_7dffa_row21_col11 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_7dffa_row22_col10 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_7dffa_row22_col11 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_7dffa_row23_col10 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_7dffa_row23_col11 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_7dffa_row24_col11 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_7dffa_row25_col11 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_7dffa_row26_col10 {
#   background-color: #c3c3c3;
#   color: #000000;
# }
# #T_7dffa_row27_col10 {
#   background-color: #dddddd;
#   color: #000000;
# }
# </style>
# <table id="T_7dffa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Typ</th>
#       <th class="col_heading level0 col1" >Version</th>
#       <th class="col_heading level0 col2" >Pooling</th>
#       <th class="col_heading level0 col3" >Optimizer</th>
#       <th class="col_heading l

# %%
with open('../sections/evaluation/gridsearch-results.tex', 'w') as f:
    f.write(styled_df.to_latex(convert_css=True))

# %%
download('../sections/evaluation/gridsearch-results.tex')

# %%
# Finalization and profiling statistics

df = pd.DataFrame(load_trial_data())
df['max_train_acc_pct'] = df['train_epoch_acc'].apply(lambda x: np.amax(x) * 100)
df['max_validation_acc_pct'] = df['validation_epoch_acc'].apply(lambda x: np.amax(x) * 100)
df = pd.DataFrame(df.nlargest(10, ['max_validation_acc_pct']))

def get_model_size(trial_id):
    with tempfile.TemporaryDirectory() as dir:
        shutil.copyfile(f'/content/drive/MyDrive/finalization-tflite-model-{trial_id}.zip', f'{dir}/model.zip')
        with zipfile.ZipFile(f'{dir}/model.zip') as zip_ref:
            zip_ref.extractall(f'{dir}')
        n_bytes = os.path.getsize(f'{dir}/model.tflite')
    n_megabytes = n_bytes / 1_000_000
    return n_megabytes

def get_model_finalization_log(trial_id):
    with tempfile.TemporaryDirectory() as dir:
        shutil.copyfile(f'/content/drive/MyDrive/finalization-log-{trial_id}.zip', f'{dir}/log.zip')
        with zipfile.ZipFile(f'{dir}/log.zip') as zip_ref:
            zip_ref.extractall(f'{dir}')
        log_df = pd.read_csv(f'{dir}/log.csv')
    return log_df

if model_sizes is None or model_logs is None:
    model_sizes = []
    model_logs = []
    for trial_id in df.index:
        model_sizes.append(get_model_size(trial_id))
        model_logs.append(get_model_finalization_log(trial_id))

df['model_size_mb'] = model_sizes
df['finalization_log'] = model_logs

df['finalization_epochs'] = df['finalization_log'].apply(lambda log_df: max(log_df['epoch']) + 1)
df['finalization_train_acc_pct'] = df['finalization_log'].apply(lambda log_df: max(log_df['acc']) * 100)
df['finalization_val_acc_pct'] = df['finalization_log'].apply(lambda log_df: max(log_df['val_acc']) * 100)

df['trial_rank'] = [str(i + 1) for i in range(len(df.index))]

finalization_df = df.copy()
finalization_df = finalization_df[[
    'trial_rank',
    'model_type',
    'max_validation_acc_pct',
    'max_train_acc_pct',
    'finalization_train_acc_pct',
    'finalization_val_acc_pct',
    'model_size_mb'
]]

finalization_df.rename(columns={
    'trial_rank': 'Rang',
    'model_type': 'Typ',
    'version': 'Version',
    'pooling': 'Pooling',
    'optimizer': 'Optimizer',
    'max_train_acc_pct': 'Trial Train Acc. (in \%)',
    'max_validation_acc_pct': 'Trial Val. Acc. (in \%)',
    'finalization_train_acc_pct': 'Fin. Train Acc. (in \%)',
    'finalization_val_acc_pct': 'Fin. Val. Acc. (in \%)',
    'model_size_mb': 'Größe (in MB)',
}, inplace=True)
finalization_df.reset_index(inplace=True)

del finalization_df['index']

finalization_df_styled = finalization_df.style.background_gradient(cmap='binary')
finalization_df_styled
# Out:
# <style type="text/css">
# #T_38c34_row0_col2, #T_38c34_row2_col3, #T_38c34_row2_col4, #T_38c34_row2_col6, #T_38c34_row3_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_38c34_row0_col3 {
#   background-color: #acacac;
#   color: #000000;
# }
# #T_38c34_row0_col4 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_38c34_row0_col5 {
#   background-color: #0e0e0e;
#   color: #f1f1f1;
# }
# #T_38c34_row0_col6, #T_38c34_row6_col6, #T_38c34_row8_col6 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_38c34_row1_col2 {
#   background-color: #202020;
#   color: #f1f1f1;
# }
# #T_38c34_row1_col3 {
#   background-color: #a0a0a0;
#   color: #f1f1f1;
# }
# #T_38c34_row1_col4 {
#   background-color: #252525;
#   color: #f1f1f1;
# }
# #T_38c34_row1_col5, #T_38c34_row6_col5 {
#   background-color: #070707;
#   color: #f1f1f1;
# }
# #T_38c34_row1_col6 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_38c34_row2_col2 {
#   background-color: #242424;
#   color: #f1f1f1;
# }
# #T_38c34_row2_col5 {
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_38c34_row3_col2 {
#   background-color: #696969;
#   color: #f1f1f1;
# }
# #T_38c34_row3_col3 {
#   background-color: #d2d2d2;
#   color: #000000;
# }
# #T_38c34_row3_col4 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_38c34_row3_col6, #T_38c34_row6_col3, #T_38c34_row9_col2, #T_38c34_row9_col4, #T_38c34_row9_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_38c34_row4_col2 {
#   background-color: #787878;
#   color: #f1f1f1;
# }
# #T_38c34_row4_col3 {
#   background-color: #4e4e4e;
#   color: #f1f1f1;
# }
# #T_38c34_row4_col4 {
#   background-color: #888888;
#   color: #f1f1f1;
# }
# #T_38c34_row4_col5 {
#   background-color: #1f1f1f;
#   color: #f1f1f1;
# }
# #T_38c34_row4_col6, #T_38c34_row7_col6 {
#   background-color: #5a5a5a;
#   color: #f1f1f1;
# }
# #T_38c34_row5_col2 {
#   background-color: #969696;
#   color: #f1f1f1;
# }
# #T_38c34_row5_col3 {
#   background-color: #545454;
#   color: #f1f1f1;
# }
# #T_38c34_row5_col4 {
#   background-color: #050505;
#   color: #f1f1f1;
# }
# #T_38c34_row5_col5 {
#   background-color: #9b9b9b;
#   color: #f1f1f1;
# }
# #T_38c34_row5_col6 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_38c34_row6_col2 {
#   background-color: #989898;
#   color: #f1f1f1;
# }
# #T_38c34_row6_col4 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_38c34_row7_col2 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_38c34_row7_col3 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_38c34_row7_col4 {
#   background-color: #b4b4b4;
#   color: #000000;
# }
# #T_38c34_row7_col5 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_38c34_row8_col2 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_38c34_row8_col3, #T_38c34_row9_col6 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_38c34_row8_col4 {
#   background-color: #9c9c9c;
#   color: #f1f1f1;
# }
# #T_38c34_row8_col5 {
#   background-color: #434343;
#   color: #f1f1f1;
# }
# #T_38c34_row9_col3 {
#   background-color: #fefefe;
#   color: #000000;
# }
# </style>
# <table id="T_38c34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rang</th>
#       <th class="col_heading level0 col1" >Typ</th>
#       <th class="col_heading level0 col2" >Trial Val. Acc. (in \%)</th>
#       <th class="col_heading level0 col3" >Trial Train Acc. (in \%)</th>
#       <th class="col_heading level0 col4" >Fin. Train Acc. (in \%)</th>
#       <th class="col_heading level0 col5" >Fin. Val. Acc. (in \%)</th>
#       <th class="col_heading level0 col6" >Größe (in MB)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38c34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38c34_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_38c34_row0_col1" class="data row0 col1" >1d</td>
#       <td id="T_38c34_row0_col2" class="data row0 col2" >81.907892</td>
#       <td id="T_38c34_row0_col3" class="data row0 col3" >89.161515</td>
#       <td id="T_38c34_row0_col4" class="data row0 col4" >91.260183</td>
#       <td id="T_38c34_row0_col5" class="data row0 col5" >84.030497</td>
#       <td id="T_38c34_row0_col6" class="data row0 col6" >6.911564</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38c34_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_38c34_row1_col1" class="data row1 col1" >1d</td>
#       <td id="T_38c34_row1_col2" class="data row1 col2" >81.385577</td>
#       <td id="T_38c34_row1_col3" class="data row1 col3" >89.738411</td>
#       <td id="T_38c34_row1_col4" class="data row1 col4" >95.742863</td>
#       <td id="T_38c34_row1_col5" class="data row1 col5" >84.181631</td>
#       <td id="T_38c34_row1_col6" class="data row1 col6" >154.496240</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38c34_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_38c34_row2_col1" class="data row2 col1" >2d</td>
#       <td id="T_38c34_row2_col2" class="data row2 col2" >81.312233</td>
#       <td id="T_38c34_row2_col3" class="data row2 col3" >97.293776</td>
#       <td id="T_38c34_row2_col4" class="data row2 col4" >96.778560</td>
#       <td id="T_38c34_row2_col5" class="data row2 col5" >81.327790</td>
#       <td id="T_38c34_row2_col6" class="data row2 col6" >168.531536</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38c34_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_38c34_row3_col1" class="data row3 col1" >1d</td>
#       <td id="T_38c34_row3_col2" class="data row3 col2" >80.185366</td>
#       <td id="T_38c34_row3_col3" class="data row3 col3" >87.370199</td>
#       <td id="T_38c34_row3_col4" class="data row3 col4" >90.773642</td>
#       <td id="T_38c34_row3_col5" class="data row3 col5" >84.343880</td>
#       <td id="T_38c34_row3_col6" class="data row3 col6" >3.958124</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38c34_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_38c34_row4_col1" class="data row4 col1" >1d</td>
#       <td id="T_38c34_row4_col2" class="data row4 col2" >79.940879</td>
#       <td id="T_38c34_row4_col3" class="data row4 col3" >93.586493</td>
#       <td id="T_38c34_row4_col4" class="data row4 col4" >93.006319</td>
#       <td id="T_38c34_row4_col5" class="data row4 col5" >83.690435</td>
#       <td id="T_38c34_row4_col6" class="data row4 col6" >110.534748</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38c34_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_38c34_row5_col1" class="data row5 col1" >2d</td>
#       <td id="T_38c34_row5_col2" class="data row5 col2" >79.463017</td>
#       <td id="T_38c34_row5_col3" class="data row5 col3" >93.326074</td>
#       <td id="T_38c34_row5_col4" class="data row5 col4" >96.634716</td>
#       <td id="T_38c34_row5_col5" class="data row5 col5" >81.065524</td>
#       <td id="T_38c34_row5_col6" class="data row5 col6" >10.358416</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38c34_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_38c34_row6_col1" class="data row6 col1" >1d</td>
#       <td id="T_38c34_row6_col2" class="data row6 col2" >79.418564</td>
#       <td id="T_38c34_row6_col3" class="data row6 col3" >85.229164</td>
#       <td id="T_38c34_row6_col4" class="data row6 col4" >91.141504</td>
#       <td id="T_38c34_row6_col5" class="data row6 col5" >84.179407</td>
#       <td id="T_38c34_row6_col6" class="data row6 col6" >6.911564</td>
#     </tr>
#     <tr>
#       <th id="T_38c34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38c34_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_38c34_row7_col1" class="data row7 col1" >1d</td>
#       <td id="T_38c34_row7_col2" class="data row7 col2" >78.033870</td>
#       <td id="T_38c34_row7_col3" class="data row7 col3" >85.886824</td>
#       <td id="T_38c34_row7_col4" class="data row7 col4" >91.788626</td>
#       <td id="T_38c34_row7_col5" cla

# %%
with open('../sections/evaluation/finalization-results.tex', 'w') as f:
    f.write(finalization_df_styled.to_latex(convert_css=True))

# %%
download('../sections/evaluation/finalization-results.tex')

# %%
plt.clf()
fig, axs = plt.subplots(2, 5, sharey=True)
fig.set_size_inches(3 * 5, 4 * 2)

for ax, trial_id in zip(axs.flatten(), df.index):
    val_acc = df['finalization_log'][trial_id]['val_acc']
    train_acc = df['finalization_log'][trial_id]['acc']
    ax.plot([acc * 100 for acc in val_acc], color='black')
    ax.plot([acc * 100 for acc in train_acc], color='grey')
    ax.fill_between(
        x=[i for i in range(len(val_acc))],
        y1=[acc * 100 for acc in val_acc],
        y2=[acc * 100 for acc in train_acc],
        color=(0, 0, 0, 0.05)
    )
    ax.set_title(f'Rang {list(df.index).index(trial_id) + 1} ({df["model_size_mb"][trial_id]:0.2f} MB)')
    ax.set_xlabel('Epochen')

    ax.grid(
        b = True, 
        color ='grey',
        linestyle ='-.', 
        linewidth = 0.5,
        alpha = 0.2
    )

    ax.set_ylabel('Accuracy (in %)')
    ax.set_ylim(30, 100)
    ax.set_xlim(0, 15)
    ax.axvline(len(val_acc) - 1, color='black')

    ax.axhline(78.94, color='black', linestyle=':')
    ax.axhline(70.42, color='grey', linestyle=':')

    ax.set_xticks([len(val_acc) - 1])
    es = len(val_acc) != 15

    ax.set_xticklabels([f'{len(val_acc)}{" (Early Stopping)" if es else " (Limit erreicht)"}'])

    rax = ax.twinx()
    rax.set_ylim(ax.get_ylim())
    rax.set_yticks([max([acc * 100 for acc in val_acc]), 78.94, 70.42])
    rax.set_yticklabels(['', 'Basis', 'MLP'])

plt.tight_layout()
plt.savefig(
    f'../images/shl/finalization-results-accuracy.pdf',
    dpi=1200,
    bbox_inches='tight'
)
plt.show()

# %%
download('../images/shl/finalization-results-accuracy.pdf')

# %%
plt.clf()
fig, axs = plt.subplots(2, 5, sharey=True)
fig.set_size_inches(3 * 5, 4 * 2)

for ax, trial_id in zip(axs.flatten(), df.index):
    val_loss = df['finalization_log'][trial_id]['val_loss']
    train_loss = df['finalization_log'][trial_id]['loss']
    ax.plot(val_loss, color='black')
    ax.plot(train_loss, color='grey')
    ax.fill_between(
        x=[i for i in range(len(val_loss))],
        y1=val_loss,
        y2=train_loss,
        color=(0, 0, 0, 0.05)
    )
    ax.set_title(f'Rang {list(df.index).index(trial_id) + 1} ({df["model_size_mb"][trial_id]:0.2f} MB)')
    ax.set_xlabel('Epochen')

    ax.grid(
        b = True, 
        color ='grey',
        linestyle ='-.', 
        linewidth = 0.5,
        alpha = 0.2
    )

    ax.set_ylabel('Sparse Categorical Cross Entropy (Log-Skala)')
    ax.set_yscale('log')
    ax.set_xlim(0, 15)
    ax.axvline(len(val_loss) - 1, color='black')

    ax.set_xticks([len(val_loss) - 1])
    es = len(val_loss) != 15

    ax.set_xticklabels([f'{len(val_loss)}{" (Early Stopping)" if es else " (Limit erreicht)"}'])

plt.tight_layout()
plt.savefig(
    f'../images/shl/finalization-results-loss.pdf',
    dpi=1200,
    bbox_inches='tight'
)
plt.show()

# %%
download('../images/shl/finalization-results-loss.pdf')

# %%
# Tradeoff statistics

def load_tradeoff_parameters(trial_id):
    with open(f'shl-deep-learning-on-device-evaluation/Results/{trial_id}.json') as f:
        tradeoff_data = json.loads(f.read())
    return tradeoff_data

tradeoff_data = defaultdict(list)

for trial_id in df.index:
    trial_tradeoff_data = load_tradeoff_parameters(trial_id)
    for key, value in trial_tradeoff_data.items():
        tradeoff_data[key].append(value)

for key, values in tradeoff_data.items():
    df[key] = values

df['inference_per_sample_ms'] = df['inference'].apply(lambda x: (x / 100.0) * 1000)

tradeoff_df = df[[
    'trial_rank',
    'finalization_val_acc_pct',
    'model_size_mb',
    'memory',
    'inference_per_sample_ms',
    'cpu',
    'energy_avg'
]]

tradeoff_column_print_names = {
    'trial_rank': 'Rang',
    'finalization_val_acc_pct': 'Fin. Val. Acc. (in \%)',
    'model_size_mb': 'Disk-Usage (in MB)',
    'memory': 'RAM-Usage (in MB)',
    'inference_per_sample_ms': 'Inferenzzeit (in $\\frac{ms}{Sample}$)',
    'cpu': 'CPU-Usage (in \%)',
    'energy_avg': 'Energy-Usage (in AEU v. 20)',
}

tradeoff_df_to_print = tradeoff_df.copy()
tradeoff_df_to_print.rename(columns=tradeoff_column_print_names, inplace=True)
tradeoff_df_to_print.reset_index(inplace=True)

del tradeoff_df_to_print['index']

tradeoff_df_to_print = tradeoff_df_to_print.style.background_gradient(cmap='binary')
tradeoff_df_to_print
# Out:
# <style type="text/css">
# #T_7a119_row0_col1 {
#   background-color: #0e0e0e;
#   color: #f1f1f1;
# }
# #T_7a119_row0_col2, #T_7a119_row6_col2, #T_7a119_row8_col2 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_7a119_row0_col3, #T_7a119_row6_col3, #T_7a119_row8_col3 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_7a119_row0_col4, #T_7a119_row5_col2, #T_7a119_row6_col4, #T_7a119_row8_col4 {
#   background-color: #f6f6f6;
#   color: #000000;
# }
# #T_7a119_row0_col5, #T_7a119_row0_col6, #T_7a119_row3_col2, #T_7a119_row3_col3, #T_7a119_row3_col4, #T_7a119_row3_col5, #T_7a119_row3_col6, #T_7a119_row6_col5, #T_7a119_row8_col5, #T_7a119_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_7a119_row1_col1, #T_7a119_row1_col4, #T_7a119_row6_col1 {
#   background-color: #070707;
#   color: #f1f1f1;
# }
# #T_7a119_row1_col2 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_7a119_row1_col3, #T_7a119_row1_col5, #T_7a119_row2_col2, #T_7a119_row2_col4, #T_7a119_row2_col6, #T_7a119_row3_col1, #T_7a119_row4_col6 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7a119_row1_col6, #T_7a119_row5_col6, #T_7a119_row6_col6, #T_7a119_row7_col6, #T_7a119_row8_col6, #T_7a119_row9_col6 {
#   background-color: #7f7f7f;
#   color: #f1f1f1;
# }
# #T_7a119_row2_col1 {
#   background-color: #8f8f8f;
#   color: #f1f1f1;
# }
# #T_7a119_row2_col3 {
#   background-color: #9a9a9a;
#   color: #f1f1f1;
# }
# #T_7a119_row2_col5 {
#   background-color: #131313;
#   color: #f1f1f1;
# }
# #T_7a119_row4_col1 {
#   background-color: #1f1f1f;
#   color: #f1f1f1;
# }
# #T_7a119_row4_col2, #T_7a119_row7_col2 {
#   background-color: #5a5a5a;
#   color: #f1f1f1;
# }
# #T_7a119_row4_col3 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_7a119_row4_col4, #T_7a119_row7_col4 {
#   background-color: #393939;
#   color: #f1f1f1;
# }
# #T_7a119_row4_col5, #T_7a119_row7_col5 {
#   background-color: #3b3b3b;
#   color: #f1f1f1;
# }
# #T_7a119_row5_col1 {
#   background-color: #9b9b9b;
#   color: #f1f1f1;
# }
# #T_7a119_row5_col3 {
#   background-color: #d2d2d2;
#   color: #000000;
# }
# #T_7a119_row5_col4, #T_7a119_row9_col3 {
#   background-color: #d5d5d5;
#   color: #000000;
# }
# #T_7a119_row5_col5 {
#   background-color: #d8d8d8;
#   color: #000000;
# }
# #T_7a119_row7_col1 {
#   background-color: #9e9e9e;
#   color: #f1f1f1;
# }
# #T_7a119_row7_col3 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_7a119_row8_col1 {
#   background-color: #434343;
#   color: #f1f1f1;
# }
# #T_7a119_row9_col2 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_7a119_row9_col4 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_7a119_row9_col5 {
#   background-color: #ececec;
#   color: #000000;
# }
# </style>
# <table id="T_7a119_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rang</th>
#       <th class="col_heading level0 col1" >Fin. Val. Acc. (in \%)</th>
#       <th class="col_heading level0 col2" >Disk-Usage (in MB)</th>
#       <th class="col_heading level0 col3" >RAM-Usage (in MB)</th>
#       <th class="col_heading level0 col4" >Inferenzzeit (in $\frac{ms}{Sample}$)</th>
#       <th class="col_heading level0 col5" >CPU-Usage (in \%)</th>
#       <th class="col_heading level0 col6" >Energy-Usage (in AEU v. 20)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a119_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a119_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7a119_row0_col1" class="data row0 col1" >84.030497</td>
#       <td id="T_7a119_row0_col2" class="data row0 col2" >6.911564</td>
#       <td id="T_7a119_row0_col3" class="data row0 col3" >14.400000</td>
#       <td id="T_7a119_row0_col4" class="data row0 col4" >12.000000</td>
#       <td id="T_7a119_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_7a119_row0_col6" class="data row0 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a119_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7a119_row1_col1" class="data row1 col1" >84.181631</td>
#       <td id="T_7a119_row1_col2" class="data row1 col2" >154.496240</td>
#       <td id="T_7a119_row1_col3" class="data row1 col3" >22.100000</td>
#       <td id="T_7a119_row1_col4" class="data row1 col4" >90.000000</td>
#       <td id="T_7a119_row1_col5" class="data row1 col5" >24.000000</td>
#       <td id="T_7a119_row1_col6" class="data row1 col6" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a119_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7a119_row2_col1" class="data row2 col1" >81.327790</td>
#       <td id="T_7a119_row2_col2" class="data row2 col2" >168.531536</td>
#       <td id="T_7a119_row2_col3" class="data row2 col3" >17.400000</td>
#       <td id="T_7a119_row2_col4" class="data row2 col4" >92.500000</td>
#       <td id="T_7a119_row2_col5" class="data row2 col5" >23.000000</td>
#       <td id="T_7a119_row2_col6" class="data row2 col6" >15</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a119_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7a119_row3_col1" class="data row3 col1" >84.343880</td>
#       <td id="T_7a119_row3_col2" class="data row3 col2" >3.958124</td>
#       <td id="T_7a119_row3_col3" class="data row3 col3" >14.300000</td>
#       <td id="T_7a119_row3_col4" class="data row3 col4" >8.810000</td>
#       <td id="T_7a119_row3_col5" class="data row3 col5" >11.000000</td>
#       <td id="T_7a119_row3_col6" class="data row3 col6" >13</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a119_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_7a119_row4_col1" class="data row4 col1" >83.690435</td>
#       <td id="T_7a119_row4_col2" class="data row4 col2" >110.534748</td>
#       <td id="T_7a119_row4_col3" class="data row4 col3" >16.100000</td>
#       <td id="T_7a119_row4_col4" class="data row4 col4" >73.820000</td>
#       <td id="T_7a119_row4_col5" class="data row4 col5" >21.000000</td>
#       <td id="T_7a119_row4_col6" class="data row4 col6" >15</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a119_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_7a119_row5_col1" class="data row5 col1" >81.065524</td>
#       <td id="T_7a119_row5_col2" class="data row5 col2" >10.358416</td>
#       <td id="T_7a119_row5_col3" class="data row5 col3" >15.700000</td>
#       <td id="T_7a119_row5_col4" class="data row5 col4" >22.820000</td>
#       <td id="T_7a119_row5_col5" class="data row5 col5" >13.000000</td>
#       <td id="T_7a119_row5_col6" class="data row5 col6" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a119_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_7a119_row6_col1" class="data row6 col1" >84.179407</td>
#       <td id="T_7a119_row6_col2" class="data row6 col2" >6.911564</td>
#       <td id="T_7a119_row6_col3" class="data row6 col3" >14.400000</td>
#       <td id="T_7a119_row6_col4" class="data row6 col4" >12.030000</td>
#       <td id="T_7a119_row6_col5" class="data row6 col5" >11.000000</td>
#       <td id="T_7a119_row6_col6" class="data row6 col6" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a119_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_7a119_row7_col1" class="data row7 col1" >81.014401</td>
#       <td id="T_7a119_row7_col2" class="data row7 col2" >110.534748</td>
#       <td id="T_7a119_row7_col3" class="data row7 col3" >16.300000</td>
#       <td id="T_7a119_row7_col4" class="data row7 col4" >73.700000</td>
#       <td id="T_7a119_row7_col5" class="data row7 col5" >21.000000</td>
#       <td id="T_7a119_row7_col6" class="data row7 col6" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7a119_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a119_row8_col0" class="data row8 col0" >9</td>

# %%
with open('../sections/evaluation/tradeoff-results.tex', 'w') as f:
    f.write(tradeoff_df_to_print.to_latex(convert_css=True))

# %%
download('../sections/evaluation/tradeoff-results.tex')

# %%
# !sudo apt-get install texlive-latex-recommended 
# !sudo apt install texlive-latex-extra
# !sudo apt install dvipng
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6
#   libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13
#   lmodern poppler-data t1utils tex-common texlive-base texlive-binaries
#   texlive-latex-base
# Suggested packages:
#   fonts-noto poppler-utils ghostscript fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum debhelper gv
#   | postscript-viewer perl-tk xpdf-reader | pdf-viewer texlive-latex-base-doc
#   texlive-latex-recommended-doc texlive-pstricks
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-lmodern fonts-noto-mono libcupsfilters1
#   libcupsimage2 libgs9 libgs9-common libijs-0.35 libjbig2dec0 libkpathsea6
#   libpotrace0 libptexenc1 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13
#   lmodern poppler-data t1utils tex-common texlive-base texlive-binaries
#   texlive-latex-base texlive-latex-recommended
# 0 upgraded, 24 newly installed, 0 to remove and 40 not upgraded.
# Need to get 68.4 MB of archives.
# After this operation, 223 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-recommended all 2017.20180305-1 [14.9 MB]
# Fetched 68.4 MB in 3s (22.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 24.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 148492 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../02-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../03-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../04-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../05-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../06-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../07-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../08-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../09-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.14_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../10-libgs9_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../11-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../12-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../13-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../14-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../15-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../16-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../17-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../18-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../19-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../20-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../21-texlive-base_2017.20180305-1_all.deb ...
# Unpacking texlive-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../22-texlive-latex-base_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../23-texlive-latex-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-recommended (2017.20180305-1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up poppler-data (0.4.8-2) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up t1utils (1.41-2) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up libpotrace0 (1.14-2) ...
# Setting up libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up texlive-base (2017.20180305-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up texlive-latex-base (2017.20180305-1) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up texlive-latex-recommended (2017.20180305-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-lato fonts-texgyre javascript-common libjs-jquery libruby2.5
#   preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration tex-gyre texlive-fonts-recommended texlive-pictures
#   texlive-plain-generic tipa
# Suggested packages:
#   apache2 | lighttpd | httpd ri ruby-dev bundler texlive-fonts-recommended-doc
#   python-pygments icc-profiles libfile-which-perl
#   libspreadsheet-parseexcel-perl texlive-latex-extra-doc dot2tex prerex
#   ruby-tcltk | libtcltk-ruby texlive-pictures-doc vprerex
# The following NEW packages will be installed:
#   fonts-lato fonts-texgyre javascript-common libjs-jquery libruby2.5
#   preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration tex-gyre texlive-fonts-recommended texlive-latex-extra
#   texlive-pictures texlive-plain-generic tipa
# 0 upgraded, 21 newly installed, 0 to remove and 40 not upgraded.
# Need to get 66.6 MB of archives.
# After this operation, 216 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lato all 2.0-2 [2,698 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-texgyre all 20160520-1 [8,761 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 rubygems-integration all 1.11 [4,994 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ruby2.5 amd64 2.5.1-1ubuntu1.10 [48.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby amd64 1:2.5.1 [5,712 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rake all 12.3.1-1ubuntu0.1 [44.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-did-you-mean all 1.2.0-2 [9,700 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-minitest all 5.10.3-1 [38.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-power-assert all 0.3.0-1 [7,952 B]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-test-unit all 3.2.5-1 [61.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libruby2.5 amd64 2.5.1-1ubuntu1.10 [3,071 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 preview-latex-style all 11.91-1ubuntu1 [185 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tex-gyre all 20160520-1 [4,998 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-fonts-recommended all 2017.20180305-1 [5,262 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-pictures all 2017.20180305-1 [4,026 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-latex-extra all 2017.20180305-2 [10.6 MB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-plain-generic all 2017.20180305-2 [23.6 MB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tipa all 2:1.3-20 [2,978 kB]
# Fetched 66.6 MB in 3s (20.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 21.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-lato.
# (Reading database ... 155826 files and directories currently installed.)
# Preparing to unpack .../00-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../01-fonts-texgyre_20160520-1_all.deb ...
# Unpacking fonts-texgyre (20160520-1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../02-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../03-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../04-rubygems-integration_1.11_all.deb ...
# Unpacking rubygems-integration (1.11) ...
# Selecting previously unselected package ruby2.5.
# Preparing to unpack .../05-ruby2.5_2.5.1-1ubuntu1.10_amd64.deb ...
# Unpacking ruby2.5 (2.5.1-1ubuntu1.10) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../06-ruby_1%3a2.5.1_amd64.deb ...
# Unpacking ruby (1:2.5.1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../07-rake_12.3.1-1ubuntu0.1_all.deb ...
# Unpacking rake (12.3.1-1ubuntu0.1) ...
# Selecting previously unselected package ruby-did-you-mean.
# Preparing to unpack .../08-ruby-did-you-mean_1.2.0-2_all.deb ...
# Unpacking ruby-did-you-mean (1.2.0-2) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../09-ruby-minitest_5.10.3-1_all.deb ...
# Unpacking ruby-minitest (5.10.3-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../10-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../11-ruby-power-assert_0.3.0-1_all.deb ...
# Unpacking ruby-power-assert (0.3.0-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../12-ruby-test-unit_3.2.5-1_all.deb ...
# Unpacking ruby-test-unit (3.2.5-1) ...
# Selecting previously unselected package libruby2.5:amd64.
# Preparing to unpack .../13-libruby2.5_2.5.1-1ubuntu1.10_amd64.deb ...
# Unpacking libruby2.5:amd64 (2.5.1-1ubuntu1.10) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../14-preview-latex-style_11.91-1ubuntu1_all.deb ...
# Unpacking preview-latex-style (11.91-1ubuntu1) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../15-tex-gyre_20160520-1_all.deb ...
# Unpacking tex-gyre (20160520-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../16-texlive-fonts-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-fonts-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../17-texlive-pictures_2017.20180305-1_all.deb ...
# Unpacking texlive-pictures (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../18-texlive-latex-extra_2017.20180305-2_all.deb ...
# Unpacking texlive-latex-extra (2017.20180305-2) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../19-texlive-plain-generic_2017.20180305-2_all.deb ...
# Unpacking texlive-plain-generic (2017.20180305-2) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../20-tipa_2%3a1.3-20_all.deb ...
# Unpacking tipa (2:1.3-20) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up texlive-pictures (2017.20180305-1) ...
# Setting up tex-gyre (20160520-1) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up preview-latex-style (11.91-1ubuntu1) ...
# Setting up fonts-texgyre (20160520-1) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up ruby-did-you-mean (1.2.0-2) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up rubygems-integration (1.11) ...
# Setting up javascript-common (11) ...
# Setting up texlive-fonts-recommended (2017.20180305-1) ...
# Setting up texlive-plain-generic (2017.20180305-2) ...
# Setting up ruby-minitest (5.10.3-1) ...
# Setting up ruby-power-assert (0.3.0-1) ...
# Setting up texlive-latex-extra (2017.20180305-2) ...
# Setting up ruby-test-unit (3.2.5-1) ...
# Setting up libruby2.5:amd64 (2.5.1-1ubuntu1.10) ...
# Setting up ruby2.5 (2.5.1-1ubuntu1.10) ...
# Setting up ruby (1:2.5.1) ...
# Setting up rake (12.3.1-1ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for tex-common (6.09) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Running mktexlsr. This may take some time... done.
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   ghostscript gsfonts
# Suggested packages:
#   ghostscript-x
# The following NEW packages will be installed:
#   dvipng ghostscript gsfonts
# 0 upgraded, 3 newly installed, 0 to remove and 40 not upgraded.
# Need to get 3,250 kB of archives.
# After this operation, 4,947 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dvipng amd64 1.15-1 [78.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Fetched 3,250 kB in 1s (3,095 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package ghostscript.
# (Reading database ... 174177 files and directories currently installed.)
# Preparing to unpack .../ghostscript_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package dvipng.
# Preparing to unpack .../dvipng_1.15-1_amd64.deb ...
# Unpacking dvipng (1.15-1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up dvipng (1.15-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from matplotlib import rc

rc('text', usetex=False)

# %%
tradeoff_pairs = [
    ('finalization_val_acc_pct', 'model_size_mb'),
    ('finalization_val_acc_pct', 'memory'),
    ('finalization_val_acc_pct', 'cpu'),
    ('finalization_val_acc_pct', 'inference_per_sample_ms'),
    ('finalization_val_acc_pct', 'energy_avg'),
]

param_names = {
    'finalization_val_acc_pct': 'Validation Accuracy (in %)',
    'model_size_mb': 'Modellgröße (in MB)',
    'memory': 'RAM-Usage (in %)',
    'cpu': 'CPU-Usage (in %)',
    'energy_avg': 'Energy-Usage (in AEU v. 20)',
    'inference_per_sample_ms': 'Inferenzzeit (in ms)',
}

plt.clf()
fig, axs = plt.subplots(1, len(tradeoff_pairs), sharex=True)
fig.set_size_inches(3 * len(tradeoff_pairs), 4)

ordered_df = df.sort_values(by=['finalization_val_acc_pct'], inplace=False, ascending=False)

for ax, (param1, param2) in zip(axs.flatten(), tradeoff_pairs):
    ax.grid(
        b = True, 
        color ='grey',
        linestyle ='-.', 
        linewidth = 0.5,
        alpha = 0.2
    )

    ax.set_xlabel(param_names[param1])
    ax.set_ylabel(param_names[param2])
    ax.scatter(
        ordered_df[param1],
        ordered_df[param2],
        color='black'
    )
    ax.plot(
        ordered_df[param1],
        ordered_df[param2],
        color='black'
    )

plt.tight_layout()
plt.savefig(
    f'../images/shl/tradeoff-results.pdf',
    dpi=1200,
    bbox_inches='tight'
)
plt.show()

# %%
download('../images/shl/tradeoff-results.pdf')
